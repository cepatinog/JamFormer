# %%
import os
import glob
from music21 import converter, key, interval, pitch, midi

# CONFIGURATION

input_dir = "/home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD"          # <- Ajusta esta ruta
output_dir = "/home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am"  # <- Carpeta de salida

os.makedirs(output_dir, exist_ok=True)

MIN_PITCH = 48
MAX_PITCH = 95

def get_pitch_range(part):
    """Returns (min, max) pitch considering Notes and Chords."""
    pitches = []
    for n in part.flatten().notes:
        if n.isNote:
            pitches.append(n.pitch.midi)
        elif n.isChord:
            top_note = max(n.pitches, key=lambda p: p.midi)
            pitches.append(top_note.midi)
    return (min(pitches), max(pitches)) if pitches else (None, None)

def transpose_to_c_or_am(score):
    original_key = score.analyze('key')
    print(f"  Detected key: {original_key.tonic.name} {original_key.mode}")

    target_key = key.Key('C') if original_key.mode == 'major' else key.Key('A')
    i = interval.Interval(original_key.tonic, target_key.tonic)
    transposed = score.transpose(i)

    print(f"  Transposed by {i.niceName}")
    return transposed, i

def adjust_octaves(score):
    part = score.parts[0]
    min_pitch, max_pitch = get_pitch_range(part)

    if min_pitch is None:
        print("  ⚠️ No pitches found.")
        return score

    print(f"  Pitch range after tonal transposition: {min_pitch}–{max_pitch}")

    shift = 0
    while min_pitch + shift < MIN_PITCH:
        shift += 12
    while max_pitch + shift > MAX_PITCH:
        shift -= 12

    print(f"  Octave shift applied: {shift:+} semitonos")

    if shift != 0:
        score = score.transpose(shift)

    return score

# PROCESS ALL FILES

midi_files = glob.glob(os.path.join(input_dir, "**/*.mid"), recursive=True)
print(f"\n MIDI files found: {len(midi_files)}")

for path in midi_files:
    try:
        filename = os.path.basename(path)
        print(f"\n🎵 Processing {filename}")

        score = converter.parse(path)

        # Original range 
        original_min, original_max = get_pitch_range(score.parts[0])
        print(f"  Original range: {original_min}–{original_max}")

        # Harmonic transposition + octave adjustment
        score, i = transpose_to_c_or_am(score)
        score = adjust_octaves(score)

        # File name with transposition info
        semitones = i.chromatic.directed
        new_name = filename.replace(".mid", f"_shift{semitones:+}.mid")
        out_path = os.path.join(output_dir, new_name)

        # Save transposed file
        mf = midi.translate.music21ObjectToMidiFile(score)
        mf.open(out_path, 'wb')
        mf.write()
        mf.close()

        print(f"  ✅ Saved: {out_path}")

    except Exception as e:
        print(f"  ❌ Error processing {filename}: {e}")
# Out:
# 🎯 Archivos MIDI encontrados: 441
#
# 🎵 Procesando MichaelBrecker_DeltaCityBlues_FINAL.mid
#   Rango original: 44–77
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 41–74
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MichaelBrecker_DeltaCityBlues_FINAL_shift-3.mid
#
# 🎵 Procesando RoyEldridge_BodyAndSoul_FINAL.mid
#   Rango original: 55–80
#   Detected key: B- minor
#   Transposed by Minor Second
#   Pitch range after tonal transposition: 54–79
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/RoyEldridge_BodyAndSoul_FINAL_shift-1.mid
#
# 🎵 Procesando JoeLovano_ICan'tGetStarted_FINAL.mid
#   Rango original: 44–78
#   Detected key: C major
#   Transposed by Perfect Unison
#   Pitch range after tonal transposition: 44–78
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JoeLovano_ICan'tGetStarted_FINAL_shift+0.mid
#
# 🎵 Procesando WayneShorter_Dolores_FINAL.mid
#   Rango original: 51–74
#   Detected key: C minor
#   Transposed by Major Sixth
#   Pitch range after tonal transposition: 60–83
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/WayneShorter_Dolores_FINAL_shift+9.mid
#
# 🎵 Procesando SidneyBechet_BabyWon'tYouPleaseComeHome_FINAL.mid
#   Rango original: 61–79
#   Detected key: G minor
#   Transposed by Major Second
#   Pitch range after tonal transposition: 63–81
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/SidneyBechet_BabyWon'tYouPleaseComeHome_FINAL_shift+2.mid
#
# 🎵 Procesando DonEllis_YouSteppedOutOfADream-2_FINAL.mid
#   Rango original: 57–78
#   Detected key: D major
#   Transposed by Major Second
#   Pitch range after tonal transposition: 55–76
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DonEllis_YouSteppedOutOfADream-2_FINAL_shift-2.mid
#
# 🎵 Procesando JoeHenderson_In'NOut-2_FINAL.mid
#   Rango original: 46–83
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 36–73
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JoeHenderson_In'NOut-2_FINAL_shift-10.mid
#
# 🎵 Procesando MilesDavis_MilesRunsTheVoodooDown-1_FINAL.mid
#   Rango original: 53–90
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 57–94
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MilesDavis_MilesRunsTheVoodooDown-1_FINAL_shift+4.mid
#
# 🎵 Procesando BranfordMarsalis_U.M.M.G._FINAL.mid
#   Rango original: 44–85
#   Detected key: C# major
#   Transposed by Diminished Unison
#   Pitch range after tonal transposition: 43–84
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/BranfordMarsalis_U.M.M.G._FINAL_shift-1.mid
#
# 🎵 Procesando WayneShorter_SpeakNoEvil_FINAL.mid
#   Rango original: 45–78
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 49–82
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/WayneShorter_SpeakNoEvil_FINAL_shift+4.mid
#
# 🎵 Procesando LeeKonitz_Wow-1_FINAL.mid
#   Rango original: 57–78
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 52–73
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LeeKonitz_Wow-1_FINAL_shift-5.mid
#
# 🎵 Procesando JohnColtrane_26=2_FINAL.mid
#   Rango original: 45–75
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 40–70
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JohnColtrane_26=2_FINAL_shift-5.mid
#
# 🎵 Procesando JohnColtrane_BlueTrain_FINAL.mid
#   Rango original: 51–77
#   Detected key: A- major
#   Transposed by Minor Sixth
#   Pitch range after tonal transposition: 43–69
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JohnColtrane_BlueTrain_FINAL_shift-8.mid
#
# 🎵 Procesando HenryAllen_BabyWon'tYouPleaseComeHome_FINAL.mid
#   Rango original: 55–81
#   Detected key: G minor
#   Transposed by Major Second
#   Pitch range after tonal transposition: 57–83
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/HenryAllen_BabyWon'tYouPleaseComeHome_FINAL_shift+2.mid
#
# 🎵 Procesando JJJohnson_Teapot_FINAL.mid
#   Rango original: 48–72
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 52–76
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JJJohnson_Teapot_FINAL_shift+4.mid
#
# 🎵 Procesando WoodyShaw_DatDere_FINAL.mid
#   Rango original: 55–83
#   Detected key: C minor
#   Transposed by Major Sixth
#   Pitch range after tonal transposition: 64–92
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/WoodyShaw_DatDere_FINAL_shift+9.mid
#
# 🎵 Procesando LionelHampton_Runnin'Wild_FINAL.mid
#   Rango original: 55–89
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 45–79
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LionelHampton_Runnin'Wild_FINAL_shift-10.mid
#
# 🎵 Procesando JohnColtrane_Soultrane_FINAL.mid
#   Rango original: 51–75
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 48–72
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JohnColtrane_Soultrane_FINAL_shift-3.mid
#
# 🎵 Procesando ChrisPotter_PopTune#1_FINAL.mid
#   Rango original: 44–87
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 41–84
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/ChrisPotter_PopTune#1_FINAL_shift-3.mid
#
# 🎵 Procesando SonnyRollins_BlueSeven-1_FINAL.mid
#   Rango original: 44–76
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 41–73
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/SonnyRollins_BlueSeven-1_FINAL_shift-3.mid
#
# 🎵 Procesando HankMobley_LadyBird_FINAL.mid
#   Rango original: 45–74
#   Detected key: C minor
#   Transposed by Major Sixth
#   Pitch range after tonal transposition: 54–83
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/HankMobley_LadyBird_FINAL_shift+9.mid
#
# 🎵 Procesando LesterYoung_D.B.Blues_FINAL.mid
#   Rango original: 48–74
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 38–64
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LesterYoung_D.B.Blues_FINAL_shift-10.mid
#
# 🎵 Procesando DavidLiebman_Nica'sDream_FINAL.mid
#   Rango original: 56–89
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 53–86
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DavidLiebman_Nica'sDream_FINAL_shift-3.mid
#
# 🎵 Procesando HankMobley_Doodlin'_FINAL.mid
#   Rango original: 49–73
#   Detected key: C# major
#   Transposed by Diminished Unison
#   Pitch range after tonal transposition: 48–72
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/HankMobley_Doodlin'_FINAL_shift-1.mid
#
# 🎵 Procesando LeeKonitz_AllTheThingsYouAre_FINAL.mid
#   Rango original: 51–84
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 55–88
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LeeKonitz_AllTheThingsYouAre_FINAL_shift+4.mid
#
# 🎵 Procesando JoshuaRedman_SweetSorrow_FINAL.mid
#   Rango original: 45–86
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 42–83
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JoshuaRedman_SweetSorrow_FINAL_shift-3.mid
#
# 🎵 Procesando JohnColtrane_GiantSteps-2_FINAL.mid
#   Rango original: 51–75
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 48–72
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JohnColtrane_GiantSteps-2_FINAL_shift-3.mid
#
# 🎵 Procesando DonEllis_JohnnyComeLately_FINAL.mid
#   Rango original: 55–87
#   Detected key: G minor
#   Transposed by Major Second
#   Pitch range after tonal transposition: 57–89
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DonEllis_JohnnyComeLately_FINAL_shift+2.mid
#
# 🎵 Procesando MilesDavis_Dolores_FINAL.mid
#   Rango original: 54–81
#   Detected key: C minor
#   Transposed by Major Sixth
#   Pitch range after tonal transposition: 63–90
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MilesDavis_Dolores_FINAL_shift+9.mid
#
# 🎵 Procesando BenWebster_WhereOrWhen_FINAL.mid
#   Rango original: 48–68
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 52–72
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/BenWebster_WhereOrWhen_FINAL_shift+4.mid
#
# 🎵 Procesando RexStewart_Perdido_FINAL.mid
#   Rango original: 62–90
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 52–80
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/RexStewart_Perdido_FINAL_shift-10.mid
#
# 🎵 Procesando DavidLiebman_Pablo'sStory_FINAL.mid
#   Rango original: 57–93
#   Detected key: C minor
#   Transposed by Major Sixth
#   Pitch range after tonal transposition: 66–102
#   Octave shift applied: -12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DavidLiebman_Pablo'sStory_FINAL_shift+9.mid
#
# 🎵 Procesando MichaelBrecker_MidnightVoyage_FINAL.mid
#   Rango original: 44–77
#   Detected key: C minor
#   Transposed by Major Sixth
#   Pitch range after tonal transposition: 53–86
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MichaelBrecker_MidnightVoyage_FINAL_shift+9.mid
#
# 🎵 Procesando CliffordBrown_Stompin'AtTheSavoy_FINAL.mid
#   Rango original: 55–85
#   Detected key: C# major
#   Transposed by Diminished Unison
#   Pitch range after tonal transposition: 54–84
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CliffordBrown_Stompin'AtTheSavoy_FINAL_shift-1.mid
#
# 🎵 Procesando HarryEdison_DidYouCallHerToday_FINAL.mid
#   Rango original: 57–84
#   Detected key: C# major
#   Transposed by Diminished Unison
#   Pitch range after tonal transposition: 56–83
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/HarryEdison_DidYouCallHerToday_FINAL_shift-1.mid
#
# 🎵 Procesando DavidMurray_BluesForTwo-1_FINAL.mid
#   Rango original: 44–91
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 34–81
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DavidMurray_BluesForTwo-1_FINAL_shift-10.mid
#
# 🎵 Procesando LionelHampton_Dinah_FINAL.mid
#   Rango original: 56–85
#   Detected key: A- major
#   Transposed by Minor Sixth
#   Pitch range after tonal transposition: 48–77
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LionelHampton_Dinah_FINAL_shift-8.mid
#
# 🎵 Procesando CharlieParker_StarEyes_FINAL.mid
#   Rango original: 55–79
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 52–76
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CharlieParker_StarEyes_FINAL_shift-3.mid
#
# 🎵 Procesando SteveTurre_Steve'sBlues_FINAL.mid
#   Rango original: 45–74
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 40–69
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/SteveTurre_Steve'sBlues_FINAL_shift-5.mid
#
# 🎵 Procesando LeeKonitz_Tautology_FINAL.mid
#   Rango original: 53–79
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 48–74
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LeeKonitz_Tautology_FINAL_shift-5.mid
#
# 🎵 Procesando PaulDesmond_BlueRondoALaTurk_FINAL.mid
#   Rango original: 54–80
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 49–75
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/PaulDesmond_BlueRondoALaTurk_FINAL_shift-5.mid
#
# 🎵 Procesando BobBerg_Angles_FINAL.mid
#   Rango original: 44–81
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 41–78
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/BobBerg_Angles_FINAL_shift-3.mid
#
# 🎵 Procesando JoeLovano_LittleWillieLeapsIn_FINAL.mid
#   Rango original: 44–82
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 39–77
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JoeLovano_LittleWillieLeapsIn_FINAL_shift-5.mid
#
# 🎵 Procesando WyntonMarsalis_AprilInParis_FINAL.mid
#   Rango original: 55–90
#   Detected key: C major
#   Transposed by Perfect Unison
#   Pitch range after tonal transposition: 55–90
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/WyntonMarsalis_AprilInParis_FINAL_shift+0.mid
#
# 🎵 Procesando FatsNavarro_Anthropology_No1_FINAL.mid
#   Rango original: 58–88
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 48–78
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/FatsNavarro_Anthropology_No1_FINAL_shift-10.mid
#
# 🎵 Procesando LouisArmstrong_SavoyBlues_FINAL.mid
#   Rango original: 54–81
#   Detected key: G major
#   Transposed by Perfect Fifth
#   Pitch range after tonal transposition: 47–74
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LouisArmstrong_SavoyBlues_FINAL_shift-7.mid
#
# 🎵 Procesando PatMetheny_CabinFever_FINAL.mid
#   Rango original: 46–82
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 43–79
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/PatMetheny_CabinFever_FINAL_shift-3.mid
#
# 🎵 Procesando EricDolphy_Serene_FINAL.mid
#   Rango original: 37–80
#   Detected key: E- minor
#   Transposed by Augmented Fourth
#   Pitch range after tonal transposition: 43–86
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/EricDolphy_Serene_FINAL_shift+6.mid
#
# 🎵 Procesando LouisArmstrong_GotNoBlues_FINAL.mid
#   Rango original: 57–81
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 52–76
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LouisArmstrong_GotNoBlues_FINAL_shift-5.mid
#
# 🎵 Procesando MilesDavis_BitchesBrew-2_FINAL.mid
#   Rango original: 55–90
#   Detected key: B major
#   Transposed by Major Seventh
#   Pitch range after tonal transposition: 44–79
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MilesDavis_BitchesBrew-2_FINAL_shift-11.mid
#
# 🎵 Procesando JoeHenderson_Serenity_FINAL.mid
#   Rango original: 44–77
#   Detected key: C minor
#   Transposed by Major Sixth
#   Pitch range after tonal transposition: 53–86
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JoeHenderson_Serenity_FINAL_shift+9.mid
#
# 🎵 Procesando BobBerg_NatureOfTheBeast_FINAL.mid
#   Rango original: 44–81
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 41–78
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/BobBerg_NatureOfTheBeast_FINAL_shift-3.mid
#
# 🎵 Procesando PatMetheny_NothingPersonal_FINAL.mid
#   Rango original: 45–80
#   Detected key: G minor
#   Transposed by Major Second
#   Pitch range after tonal transposition: 47–82
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/PatMetheny_NothingPersonal_FINAL_shift+2.mid
#
# 🎵 Procesando LeeMorgan_TheSidewinder_FINAL.mid
#   Rango original: 53–84
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 50–81
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LeeMorgan_TheSidewinder_FINAL_shift-3.mid
#
# 🎵 Procesando JohnColtrane_Oleo_FINAL.mid
#   Rango original: 50–74
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 40–64
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JohnColtrane_Oleo_FINAL_shift-10.mid
#
# 🎵 Procesando DavidLiebman_Pendulum_FINAL.mid
#   Rango original: 56–91
#   Detected key: D major
#   Transposed by Major Second
#   Pitch range after tonal transposition: 54–89
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DavidLiebman_Pendulum_FINAL_shift-2.mid
#
# 🎵 Procesando DavidLiebman_I'veGotYouUnderMySkin_FINAL.mid
#   Rango original: 56–88
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 53–85
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DavidLiebman_I'veGotYouUnderMySkin_FINAL_shift-3.mid
#
# 🎵 Procesando FreddieHubbard_DolphinDance_FINAL.mid
#   Rango original: 57–84
#   Detected key: G minor
#   Transposed by Major Second
#   Pitch range after tonal transposition: 59–86
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/FreddieHubbard_DolphinDance_FINAL_shift+2.mid
#
# 🎵 Procesando DickieWells_AfterTheatreJump_FINAL.mid
#   Rango original: 45–72
#   Detected key: C# major
#   Transposed by Diminished Unison
#   Pitch range after tonal transposition: 44–71
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DickieWells_AfterTheatreJump_FINAL_shift-1.mid
#
# 🎵 Procesando SteveTurre_DatDere_FINAL.mid
#   Rango original: 43–78
#   Detected key: C minor
#   Transposed by Major Sixth
#   Pitch range after tonal transposition: 52–87
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/SteveTurre_DatDere_FINAL_shift+9.mid
#
# 🎵 Procesando LouisArmstrong_GutBucketBlues_FINAL.mid
#   Rango original: 62–77
#   Detected key: C minor
#   Transposed by Major Sixth
#   Pitch range after tonal transposition: 71–86
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LouisArmstrong_GutBucketBlues_FINAL_shift+9.mid
#
# 🎵 Procesando SonnyStitt_BlueMode_FINAL.mid
#   Rango original: 49–74
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 39–64
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/SonnyStitt_BlueMode_FINAL_shift-10.mid
#
# 🎵 Procesando EricDolphy_245_FINAL.mid
#   Rango original: 52–84
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 42–74
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/EricDolphy_245_FINAL_shift-10.mid
#
# 🎵 Procesando PepperAdams_HowHighTheMoon_FINAL.mid
#   Rango original: 44–67
#   Detected key: G minor
#   Transposed by Major Second
#   Pitch range after tonal transposition: 46–69
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/PepperAdams_HowHighTheMoon_FINAL_shift+2.mid
#
# 🎵 Procesando BobBerg_SecondSight_FINAL.mid
#   Rango original: 48–79
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 38–69
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/BobBerg_SecondSight_FINAL_shift-10.mid
#
# 🎵 Procesando WoodyShaw_Imagination_FINAL.mid
#   Rango original: 55–82
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 52–79
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/WoodyShaw_Imagination_FINAL_shift-3.mid
#
# 🎵 Procesando BennyGoodman_HandfulOfKeys_FINAL.mid
#   Rango original: 62–87
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 66–91
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/BennyGoodman_HandfulOfKeys_FINAL_shift+4.mid
#
# 🎵 Procesando PaulDesmond_TheGirlFromEast9thStreet_FINAL.mid
#   Rango original: 57–79
#   Detected key: A- major
#   Transposed by Minor Sixth
#   Pitch range after tonal transposition: 49–71
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/PaulDesmond_TheGirlFromEast9thStreet_FINAL_shift-8.mid
#
# 🎵 Procesando HankMobley_Remember_FINAL.mid
#   Rango original: 47–75
#   Detected key: C# major
#   Transposed by Diminished Unison
#   Pitch range after tonal transposition: 46–74
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/HankMobley_Remember_FINAL_shift-1.mid
#
# 🎵 Procesando JohnnyDodds_HeebieJeebies_FINAL.mid
#   Rango original: 69–85
#   Detected key: A- major
#   Transposed by Minor Sixth
#   Pitch range after tonal transposition: 61–77
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JohnnyDodds_HeebieJeebies_FINAL_shift-8.mid
#
# 🎵 Procesando CliffordBrown_Daahoud_FINAL.mid
#   Rango original: 58–85
#   Detected key: E- minor
#   Transposed by Augmented Fourth
#   Pitch range after tonal transposition: 64–91
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CliffordBrown_Daahoud_FINAL_shift+6.mid
#
# 🎵 Procesando SonnyRollins_VierdBlues_FINAL.mid
#   Rango original: 46–73
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 36–63
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/SonnyRollins_VierdBlues_FINAL_shift-10.mid
#
# 🎵 Procesando ColemanHawkins_It'sOnlyAPapermoon_FINAL.mid
#   Rango original: 47–72
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 42–67
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/ColemanHawkins_It'sOnlyAPapermoon_FINAL_shift-5.mid
#
# 🎵 Procesando DonByas_HarvardBlues-2_FINAL.mid
#   Rango original: 48–70
#   Detected key: F# major
#   Transposed by Augmented Fourth
#   Pitch range after tonal transposition: 42–64
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DonByas_HarvardBlues-2_FINAL_shift-6.mid
#
# 🎵 Procesando KaiWinding_Tiny'sBlues_FINAL.mid
#   Rango original: 46–72
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 41–67
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/KaiWinding_Tiny'sBlues_FINAL_shift-5.mid
#
# 🎵 Procesando KidOry_SavoyBlues_FINAL.mid
#   Rango original: 43–67
#   Detected key: G major
#   Transposed by Perfect Fifth
#   Pitch range after tonal transposition: 36–60
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/KidOry_SavoyBlues_FINAL_shift-7.mid
#
# 🎵 Procesando JohnnyHodges_Bunny_FINAL.mid
#   Rango original: 55–74
#   Detected key: C major
#   Transposed by Perfect Unison
#   Pitch range after tonal transposition: 55–74
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JohnnyHodges_Bunny_FINAL_shift+0.mid
#
# 🎵 Procesando CliffordBrown_I'llRememberApril_FINAL.mid
#   Rango original: 53–82
#   Detected key: G major
#   Transposed by Perfect Fifth
#   Pitch range after tonal transposition: 46–75
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CliffordBrown_I'llRememberApril_FINAL_shift-7.mid
#
# 🎵 Procesando SidneyBechet_ReallyTheBlues_FINAL.mid
#   Rango original: 61–82
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 51–72
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/SidneyBechet_ReallyTheBlues_FINAL_shift-10.mid
#
# 🎵 Procesando RedGarland_Oleo_FINAL.mid
#   Rango original: 36–69
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 26–59
#   Octave shift applied: +24 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/RedGarland_Oleo_FINAL_shift-10.mid
#
# 🎵 Procesando SteveTurre_IfIWereABell_FINAL.mid
#   Rango original: 48–74
#   Detected key: D minor
#   Transposed by Perfect Fifth
#   Pitch range after tonal transposition: 55–81
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/SteveTurre_IfIWereABell_FINAL_shift+7.mid
#
# 🎵 Procesando BobBerg_IDidn'tKnowWhatTimeItWas_FINAL.mid
#   Rango original: 45–79
#   Detected key: D minor
#   Transposed by Perfect Fifth
#   Pitch range after tonal transposition: 52–86
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/BobBerg_IDidn'tKnowWhatTimeItWas_FINAL_shift+7.mid
#
# 🎵 Procesando PaulDesmond_BossaAntigua_FINAL.mid
#   Rango original: 55–77
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 59–81
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/PaulDesmond_BossaAntigua_FINAL_shift+4.mid
#
# 🎵 Procesando CharlieParker_Billie'sBounce_FINAL.mid
#   Rango original: 52–80
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 47–75
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CharlieParker_Billie'sBounce_FINAL_shift-5.mid
#
# 🎵 Procesando LeeMorgan_BlueTrain_FINAL.mid
#   Rango original: 54–84
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 51–81
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LeeMorgan_BlueTrain_FINAL_shift-3.mid
#
# 🎵 Procesando GerryMulligan_WalkingShoes_FINAL.mid
#   Rango original: 38–68
#   Detected key: G major
#   Transposed by Perfect Fifth
#   Pitch range after tonal transposition: 31–61
#   Octave shift applied: +24 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/GerryMulligan_WalkingShoes_FINAL_shift-7.mid
#
# 🎵 Procesando JJJohnson_Yesterdays_FINAL.mid
#   Rango original: 49–74
#   Detected key: D minor
#   Transposed by Perfect Fifth
#   Pitch range after tonal transposition: 56–81
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JJJohnson_Yesterdays_FINAL_shift+7.mid
#
# 🎵 Procesando NatAdderley_WorkSong_FINAL.mid
#   Rango original: 60–90
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 64–94
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/NatAdderley_WorkSong_FINAL_shift+4.mid
#
# 🎵 Procesando DavidMurray_AskMeNow_FINAL.mid
#   Rango original: 45–83
#   Detected key: A- major
#   Transposed by Minor Sixth
#   Pitch range after tonal transposition: 37–75
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DavidMurray_AskMeNow_FINAL_shift-8.mid
#
# 🎵 Procesando DickieWells_IGotRhythm_FINAL.mid
#   Rango original: 45–79
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 35–69
#   Octave shift applied: +24 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DickieWells_IGotRhythm_FINAL_shift-10.mid
#
# 🎵 Procesando KennyDorham_In'NOut_FINAL.mid
#   Rango original: 53–82
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 43–72
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/KennyDorham_In'NOut_FINAL_shift-10.mid
#
# 🎵 Procesando BixBeiderbecke_SinginTheBlues_FINAL.mid
#   Rango original: 58–81
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 55–78
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/BixBeiderbecke_SinginTheBlues_FINAL_shift-3.mid
#
# 🎵 Procesando LionelHampton_HighSociety_FINAL.mid
#   Rango original: 55–87
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 52–84
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LionelHampton_HighSociety_FINAL_shift-3.mid
#
# 🎵 Procesando DickieWells_Jo=Jo_FINAL.mid
#   Rango original: 53–74
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 50–71
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DickieWells_Jo=Jo_FINAL_shift-3.mid
#
# 🎵 Procesando MichaelBrecker_NakedSoul_FINAL.mid
#   Rango original: 47–80
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 51–84
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MichaelBrecker_NakedSoul_FINAL_shift+4.mid
#
# 🎵 Procesando JohnColtrane_BodyAndSoul_AlternateTake_FINAL.mid
#   Rango original: 48–77
#   Detected key: C# major
#   Transposed by Diminished Unison
#   Pitch range after tonal transposition: 47–76
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JohnColtrane_BodyAndSoul_AlternateTake_FINAL_shift-1.mid
#
# 🎵 Procesando BennyCarter_LongAgoAndFarAway-2_FINAL.mid
#   Rango original: 53–77
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 48–72
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/BennyCarter_LongAgoAndFarAway-2_FINAL_shift-5.mid
#
# 🎵 Procesando MichaelBrecker_IMeanYou_FINAL.mid
#   Rango original: 44–77
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 39–72
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MichaelBrecker_IMeanYou_FINAL_shift-5.mid
#
# 🎵 Procesando LionelHampton_Whispering_FINAL.mid
#   Rango original: 57–87
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 54–84
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LionelHampton_Whispering_FINAL_shift-3.mid
#
# 🎵 Procesando MiltJackson_What'sNew_FINAL.mid
#   Rango original: 55–84
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 59–88
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MiltJackson_What'sNew_FINAL_shift+4.mid
#
# 🎵 Procesando MichaelBrecker_CabinFever_FINAL.mid
#   Rango original: 44–84
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 41–81
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MichaelBrecker_CabinFever_FINAL_shift-3.mid
#
# 🎵 Procesando WayneShorter_E.S.P._FINAL.mid
#   Rango original: 45–76
#   Detected key: D minor
#   Transposed by Perfect Fifth
#   Pitch range after tonal transposition: 52–83
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/WayneShorter_E.S.P._FINAL_shift+7.mid
#
# 🎵 Procesando LesterYoung_SixCatsAndAPrince_FINAL.mid
#   Rango original: 46–72
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 36–62
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LesterYoung_SixCatsAndAPrince_FINAL_shift-10.mid
#
# 🎵 Procesando BennyCarter_It'sAWonderfulWorld-2_FINAL.mid
#   Rango original: 53–84
#   Detected key: C major
#   Transposed by Perfect Unison
#   Pitch range after tonal transposition: 53–84
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/BennyCarter_It'sAWonderfulWorld-2_FINAL_shift+0.mid
#
# 🎵 Procesando KennyDorham_PrinceAlbert_FINAL.mid
#   Rango original: 55–83
#   Detected key: A- major
#   Transposed by Minor Sixth
#   Pitch range after tonal transposition: 47–75
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/KennyDorham_PrinceAlbert_FINAL_shift-8.mid
#
# 🎵 Procesando WoodyShaw_Rosewood_FINAL.mid
#   Rango original: 54–86
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 58–90
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/WoodyShaw_Rosewood_FINAL_shift+4.mid
#
# 🎵 Procesando PaulDesmond_AloneTogether_FINAL.mid
#   Rango original: 55–80
#   Detected key: C minor
#   Transposed by Major Sixth
#   Pitch range after tonal transposition: 64–89
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/PaulDesmond_AloneTogether_FINAL_shift+9.mid
#
# 🎵 Procesando KennyWheeler_PassItOn_FINAL.mid
#   Rango original: 55–97
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 52–94
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/KennyWheeler_PassItOn_FINAL_shift-3.mid
#
# 🎵 Procesando GerryMulligan_LineForLyons_FINAL.mid
#   Rango original: 45–69
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 35–59
#   Octave shift applied: +24 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/GerryMulligan_LineForLyons_FINAL_shift-10.mid
#
# 🎵 Procesando KennyGarrett_BrotherHubbard-2_FINAL.mid
#   Rango original: 51–86
#   Detected key: D minor
#   Transposed by Perfect Fifth
#   Pitch range after tonal transposition: 58–93
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/KennyGarrett_BrotherHubbard-2_FINAL_shift+7.mid
#
# 🎵 Procesando CharlieParker_YardbirdSuite_FINAL.mid
#   Rango original: 53–74
#   Detected key: C major
#   Transposed by Perfect Unison
#   Pitch range after tonal transposition: 53–74
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CharlieParker_YardbirdSuite_FINAL_shift+0.mid
#
# 🎵 Procesando MichaelBrecker_NothingPersonal_FINAL.mid
#   Rango original: 44–80
#   Detected key: G minor
#   Transposed by Major Second
#   Pitch range after tonal transposition: 46–82
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MichaelBrecker_NothingPersonal_FINAL_shift+2.mid
#
# 🎵 Procesando SonnyRollins_Airegin_FINAL.mid
#   Rango original: 49–72
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 53–76
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/SonnyRollins_Airegin_FINAL_shift+4.mid
#
# 🎵 Procesando ArtPepper_InAMellowTone_FINAL.mid
#   Rango original: 50–91
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 47–88
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/ArtPepper_InAMellowTone_FINAL_shift-3.mid
#
# 🎵 Procesando CharlieParker_Steeplechase_FINAL.mid
#   Rango original: 55–79
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 45–69
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CharlieParker_Steeplechase_FINAL_shift-10.mid
#
# 🎵 Procesando BennyCarter_LongAgoAndFarAway-1_FINAL.mid
#   Rango original: 50–80
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 45–75
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/BennyCarter_LongAgoAndFarAway-1_FINAL_shift-5.mid
#
# 🎵 Procesando CharlieParker_Ko=Ko_FINAL.mid
#   Rango original: 51–79
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 41–69
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CharlieParker_Ko=Ko_FINAL_shift-10.mid
#
# 🎵 Procesando ChetBaker_ThereWillNeverBeAnotherYou-1_FINAL.mid
#   Rango original: 60–79
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 55–74
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/ChetBaker_ThereWillNeverBeAnotherYou-1_FINAL_shift-5.mid
#
# 🎵 Procesando KennyDorham_LadyBird_FINAL.mid
#   Rango original: 55–81
#   Detected key: C major
#   Transposed by Perfect Unison
#   Pitch range after tonal transposition: 55–81
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/KennyDorham_LadyBird_FINAL_shift+0.mid
#
# 🎵 Procesando CannonballAdderley_StarEyes_FINAL.mid
#   Rango original: 53–79
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 57–83
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CannonballAdderley_StarEyes_FINAL_shift+4.mid
#
# 🎵 Procesando JoeLovano_BodyAndSoul-1_FINAL.mid
#   Rango original: 44–76
#   Detected key: B- minor
#   Transposed by Minor Second
#   Pitch range after tonal transposition: 43–75
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JoeLovano_BodyAndSoul-1_FINAL_shift-1.mid
#
# 🎵 Procesando DonByas_HarvardBlues-1_FINAL.mid
#   Rango original: 46–65
#   Detected key: F# major
#   Transposed by Augmented Fourth
#   Pitch range after tonal transposition: 40–59
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DonByas_HarvardBlues-1_FINAL_shift-6.mid
#
# 🎵 Procesando SteveColeman_SlippedAgain_FINAL.mid
#   Rango original: 53–79
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 48–74
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/SteveColeman_SlippedAgain_FINAL_shift-5.mid
#
# 🎵 Procesando JohnColtrane_Nutty_FINAL.mid
#   Rango original: 45–80
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 35–70
#   Octave shift applied: +24 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JohnColtrane_Nutty_FINAL_shift-10.mid
#
# 🎵 Procesando ArtPepper_BluesForBlanche_FINAL.mid
#   Rango original: 49–87
#   Detected key: A- major
#   Transposed by Minor Sixth
#   Pitch range after tonal transposition: 41–79
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/ArtPepper_BluesForBlanche_FINAL_shift-8.mid
#
# 🎵 Procesando JoeHenderson_Punjab_FINAL.mid
#   Rango original: 44–79
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 41–76
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JoeHenderson_Punjab_FINAL_shift-3.mid
#
# 🎵 Procesando ZootSims_AllTheThingsYouAre_FINAL.mid
#   Rango original: 51–75
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 55–79
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/ZootSims_AllTheThingsYouAre_FINAL_shift+4.mid
#
# 🎵 Procesando WayneShorter_InfantEyes_FINAL.mid
#   Rango original: 44–77
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 41–74
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/WayneShorter_InfantEyes_FINAL_shift-3.mid
#
# 🎵 Procesando BennyGoodman_Nobody'sSweetheart_FINAL.mid
#   Rango original: 62–87
#   Detected key: A- major
#   Transposed by Minor Sixth
#   Pitch range after tonal transposition: 54–79
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/BennyGoodman_Nobody'sSweetheart_FINAL_shift-8.mid
#
# 🎵 Procesando SonnyRollins_Playin'InTheYard-1_FINAL.mid
#   Rango original: 48–74
#   Detected key: C major
#   Transposed by Perfect Unison
#   Pitch range after tonal transposition: 48–74
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/SonnyRollins_Playin'InTheYard-1_FINAL_shift+0.mid
#
# 🎵 Procesando DavidMurray_ChelseaBridge_FINAL.mid
#   Rango original: 43–81
#   Detected key: C# major
#   Transposed by Diminished Unison
#   Pitch range after tonal transposition: 42–80
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DavidMurray_ChelseaBridge_FINAL_shift-1.mid
#
# 🎵 Procesando CannonballAdderley_WorkSong_FINAL.mid
#   Rango original: 53–80
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 57–84
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CannonballAdderley_WorkSong_FINAL_shift+4.mid
#
# 🎵 Procesando GeorgeColeman_MaidenVoyage_FINAL.mid
#   Rango original: 48–75
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 43–70
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/GeorgeColeman_MaidenVoyage_FINAL_shift-5.mid
#
# 🎵 Procesando WarneMarsh_Wow-1_FINAL.mid
#   Rango original: 51–75
#   Detected key: C major
#   Transposed by Perfect Unison
#   Pitch range after tonal transposition: 51–75
#   Octave shift applied: +0 semitonos
# ...
#
# 🎵 Procesando JCHigginbotham_BabyWon'tYouPleaseComeHome_FINAL.mid
#   Rango original: 53–75
#   Detected key: G minor
#   Transposed by Major Second
#   Pitch range after tonal transposition: 55–77
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JCHigginbotham_BabyWon'tYouPleaseComeHome_FINAL_shift+2.mid
#
# 🎵 Procesando DonByas_Infidele(Cry)_FINAL.mid
#   Rango original: 48–74
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 38–64
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DonByas_Infidele(Cry)_FINAL_shift-10.mid
#
# 🎵 Procesando ChrisPotter_Anthropology_FINAL.mid
#   Rango original: 44–87
#   Detected key: C minor
#   Transposed by Major Sixth
#   Pitch range after tonal transposition: 53–96
#   Octave shift applied: -12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/ChrisPotter_Anthropology_FINAL_shift+9.mid
#
# 🎵 Procesando CannonballAdderley_HighFly_FINAL.mid
#   Rango original: 53–79
#   Detected key: C minor
#   Transposed by Major Sixth
#   Pitch range after tonal transposition: 62–88
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CannonballAdderley_HighFly_FINAL_shift+9.mid
#
# 🎵 Procesando SonnyRollins_I'llRememberApril_AlternateTake2_FINAL.mid
#   Rango original: 48–76
#   Detected key: G major
#   Transposed by Perfect Fifth
#   Pitch range after tonal transposition: 41–69
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/SonnyRollins_I'llRememberApril_AlternateTake2_FINAL_shift-7.mid
#
# 🎵 Procesando JoshuaRedman_TearsInHeaven_FINAL.mid
#   Rango original: 46–79
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 36–69
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JoshuaRedman_TearsInHeaven_FINAL_shift-10.mid
#
# 🎵 Procesando CharlieParker_Ornithology_FINAL.mid
#   Rango original: 55–77
#   Detected key: G minor
#   Transposed by Major Second
#   Pitch range after tonal transposition: 57–79
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CharlieParker_Ornithology_FINAL_shift+2.mid
#
# 🎵 Procesando MilesDavis_Oleo-2_FINAL.mid
#   Rango original: 52–82
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 42–72
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MilesDavis_Oleo-2_FINAL_shift-10.mid
#
# 🎵 Procesando FatsNavarro_GoodBait_FINAL.mid
#   Rango original: 60–89
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 50–79
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/FatsNavarro_GoodBait_FINAL_shift-10.mid
#
# 🎵 Procesando CharlieParker_ScrappleFromTheApple_FINAL.mid
#   Rango original: 54–79
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 49–74
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CharlieParker_ScrappleFromTheApple_FINAL_shift-5.mid
#
# 🎵 Procesando RoyEldridge_Undecided_FINAL.mid
#   Rango original: 59–82
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 56–79
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/RoyEldridge_Undecided_FINAL_shift-3.mid
#
# 🎵 Procesando FatsNavarro_DoubleTalk_FINAL.mid
#   Rango original: 58–89
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 62–93
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/FatsNavarro_DoubleTalk_FINAL_shift+4.mid
#
# 🎵 Procesando LouisArmstrong_OnceInAWhile_FINAL.mid
#   Rango original: 59–81
#   Detected key: C major
#   Transposed by Perfect Unison
#   Pitch range after tonal transposition: 59–81
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/LouisArmstrong_OnceInAWhile_FINAL_shift+0.mid
#
# 🎵 Procesando JohnColtrane_Impressions_1961_FINAL.mid
#   Rango original: 43–84
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 38–79
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JohnColtrane_Impressions_1961_FINAL_shift-5.mid
#
# 🎵 Procesando FreddieHubbard_SpeakNoEvil_FINAL.mid
#   Rango original: 56–87
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 60–91
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/FreddieHubbard_SpeakNoEvil_FINAL_shift+4.mid
#
# 🎵 Procesando FreddieHubbard_DownUnder_FINAL.mid
#   Rango original: 57–88
#   Detected key: A major
#   Transposed by Major Sixth
#   Pitch range after tonal transposition: 48–79
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/FreddieHubbard_DownUnder_FINAL_shift-9.mid
#
# 🎵 Procesando SonnyRollins_TheEverywhereCalypso-1_FINAL.mid
#   Rango original: 47–73
#   Detected key: C major
#   Transposed by Perfect Unison
#   Pitch range after tonal transposition: 47–73
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/SonnyRollins_TheEverywhereCalypso-1_FINAL_shift+0.mid
#
# 🎵 Procesando EricDolphy_OnGreenDolphinStreet_FINAL.mid
#   Rango original: 41–79
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 38–76
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/EricDolphy_OnGreenDolphinStreet_FINAL_shift-3.mid
#
# 🎵 Procesando MiltJackson_BemshaSwing_FINAL.mid
#   Rango original: 55–87
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 59–91
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MiltJackson_BemshaSwing_FINAL_shift+4.mid
#
# 🎵 Procesando JJJohnson_BluesInTheCloset_FINAL.mid
#   Rango original: 53–74
#   Detected key: B- major
#   Transposed by Minor Seventh
#   Pitch range after tonal transposition: 43–64
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JJJohnson_BluesInTheCloset_FINAL_shift-10.mid
#
# 🎵 Procesando KidOry_GotNoBlues_FINAL.mid
#   Rango original: 46–67
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 43–64
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/KidOry_GotNoBlues_FINAL_shift-3.mid
#
# 🎵 Procesando FatsNavarro_OurDelight_FINAL.mid
#   Rango original: 57–84
#   Detected key: A- major
#   Transposed by Minor Sixth
#   Pitch range after tonal transposition: 49–76
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/FatsNavarro_OurDelight_FINAL_shift-8.mid
#
# 🎵 Procesando PatMetheny_AllTheThingsYouAre_FINAL.mid
#   Rango original: 46–80
#   Detected key: F minor
#   Transposed by Major Third
#   Pitch range after tonal transposition: 50–84
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/PatMetheny_AllTheThingsYouAre_FINAL_shift+4.mid
#
# 🎵 Procesando CannonballAdderley_SoWhat_FINAL.mid
#   Rango original: 52–80
#   Detected key: D minor
#   Transposed by Perfect Fifth
#   Pitch range after tonal transposition: 59–87
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CannonballAdderley_SoWhat_FINAL_shift+7.mid
#
# 🎵 Procesando DavidMurray_BodyAndSoul-2_FINAL.mid
#   Rango original: 46–74
#   Detected key: D major
#   Transposed by Major Second
#   Pitch range after tonal transposition: 44–72
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DavidMurray_BodyAndSoul-2_FINAL_shift-2.mid
#
# 🎵 Procesando CharlieParker_EmbraceableYou_FINAL.mid
#   Rango original: 51–80
#   Detected key: G minor
#   Transposed by Major Second
#   Pitch range after tonal transposition: 53–82
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CharlieParker_EmbraceableYou_FINAL_shift+2.mid
#
# 🎵 Procesando WoodyShaw_Rahsaan'sRun_FINAL.mid
#   Rango original: 55–85
#   Detected key: G minor
#   Transposed by Major Second
#   Pitch range after tonal transposition: 57–87
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/WoodyShaw_Rahsaan'sRun_FINAL_shift+2.mid
#
# 🎵 Procesando DexterGordon_Dextivity_FINAL.mid
#   Rango original: 47–73
#   Detected key: C major
#   Transposed by Perfect Unison
#   Pitch range after tonal transposition: 47–73
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DexterGordon_Dextivity_FINAL_shift+0.mid
#
# 🎵 Procesando DavidMurray_BluesForTwo-2_FINAL.mid
#   Rango original: 48–76
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 45–73
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/DavidMurray_BluesForTwo-2_FINAL_shift-3.mid
#
# 🎵 Procesando PhilWoods_Strollin'WithPam_FINAL.mid
#   Rango original: 53–79
#   Detected key: A- major
#   Transposed by Minor Sixth
#   Pitch range after tonal transposition: 45–71
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/PhilWoods_Strollin'WithPam_FINAL_shift-8.mid
#
# 🎵 Procesando MilesDavis_Eighty=One_FINAL.mid
#   Rango original: 58–90
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 55–87
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MilesDavis_Eighty=One_FINAL_shift-3.mid
#
# 🎵 Procesando JoshuaRedman_BluesOnSunday_FINAL.mid
#   Rango original: 44–88
#   Detected key: A- major
#   Transposed by Minor Sixth
#   Pitch range after tonal transposition: 36–80
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JoshuaRedman_BluesOnSunday_FINAL_shift-8.mid
#
# 🎵 Procesando ChetBaker_ThereWillNeverBeAnotherYou-2_FINAL.mid
#   Rango original: 59–77
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 54–72
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/ChetBaker_ThereWillNeverBeAnotherYou-2_FINAL_shift-5.mid
#
# 🎵 Procesando JoeHenderson_TotemPole_FINAL.mid
#   Rango original: 46–77
#   Detected key: E- minor
#   Transposed by Augmented Fourth
#   Pitch range after tonal transposition: 52–83
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JoeHenderson_TotemPole_FINAL_shift+6.mid
#
# 🎵 Procesando BranfordMarsalis_HousedFromEdward-1_FINAL.mid
#   Rango original: 44–77
#   Detected key: F major
#   Transposed by Perfect Fourth
#   Pitch range after tonal transposition: 39–72
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/BranfordMarsalis_HousedFromEdward-1_FINAL_shift-5.mid
#
# 🎵 Procesando PaulDesmond_Alianca-1_FINAL.mid
#   Rango original: 57–75
#   Detected key: G minor
#   Transposed by Major Second
#   Pitch range after tonal transposition: 59–77
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/PaulDesmond_Alianca-1_FINAL_shift+2.mid
#
# 🎵 Procesando JoeLovano_Work_FINAL.mid
#   Rango original: 55–88
#   Detected key: F# major
#   Transposed by Augmented Fourth
#   Pitch range after tonal transposition: 49–82
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/JoeLovano_Work_FINAL_shift-6.mid
#
# 🎵 Procesando MilesDavis_BluesByFive_FINAL.mid
#   Rango original: 58–86
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 55–83
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MilesDavis_BluesByFive_FINAL_shift-3.mid
#
# 🎵 Procesando ChetBaker_You'dBeSoNiceToComeHomeTo_FINAL.mid
#   Rango original: 53–81
#   Detected key: G minor
#   Transposed by Major Second
#   Pitch range after tonal transposition: 55–83
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/ChetBaker_You'dBeSoNiceToComeHomeTo_FINAL_shift+2.mid
#
# 🎵 Procesando CliffordBrown_I'llRememberApril_AlternateTake2_FINAL.mid
#   Rango original: 53–81
#   Detected key: G major
#   Transposed by Perfect Fifth
#   Pitch range after tonal transposition: 46–74
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/CliffordBrown_I'llRememberApril_AlternateTake2_FINAL_shift-7.mid
#
# 🎵 Procesando BennyGoodman_TigerRag-1_FINAL.mid
#   Rango original: 51–72
#   Detected key: A- major
#   Transposed by Minor Sixth
#   Pitch range after tonal transposition: 43–64
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/BennyGoodman_TigerRag-1_FINAL_shift-8.mid
#
# 🎵 Procesando WayneShorter_Eighty=One_FINAL.mid
#   Rango original: 48–77
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 45–74
#   Octave shift applied: +12 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/WayneShorter_Eighty=One_FINAL_shift-3.mid
#
# 🎵 Procesando SidneyBechet_Summertime_FINAL.mid
#   Rango original: 57–81
#   Detected key: G minor
#   Transposed by Major Second
#   Pitch range after tonal transposition: 59–83
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/SidneyBechet_Summertime_FINAL_shift+2.mid
#
# 🎵 Procesando MilesDavis_VierdBlues_FINAL.mid
#   Rango original: 61–75
#   Detected key: E- major
#   Transposed by Minor Third
#   Pitch range after tonal transposition: 58–72
#   Octave shift applied: +0 semitonos
#   ✅ Guardado: /home/cepatinog/smc-assignments/final_project/my_jazz_project/data/midi_files/WjazzD_C_Am/MilesDavis_VierdBlues_FINAL_shift-3.mid
